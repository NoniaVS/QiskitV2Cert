# %% [markdown]
# ## Section 1. Perform Quantum Operations

# %% [markdown]
# #### 1. Which will raise an error?

# %% [markdown]
# **a.**
# ```
# op1 = SparsePauliOp.from_sparse_list(
#     [('XXYY', [1, 2, 3, 4], 1.0), ('YY', [1,3], -1+1j)]
# )
# op2 = Pauli('-XX')
# ```
#
# **b.**
# ```
# op1 = SparsePauliOp(['YIXYI', 'IYIYI'],
#               coeffs = [1.0, -1+1j])
# op2 = Pauli('iXX')
# ```
#
# **c.**
# ```
# op1 = SparsePauliOp.from_list(
#     [('XXYY', [1, 2, 4], 1.0), ('YY', [1,3], -1+1j)]
# )
# op2 = Pauli(['XX', i])
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: c**
#
# </details>

# %% [markdown]
# #### 2. Which one is correct about Operator class?

# %% [markdown]
# **a.**
# ```
# op1 = Operator(CXGate())
# ```
#
# **b.**
# ```
# circ = QuantumCircuit(1)
# circ.h(0)
# circ.measure_all()
# op1 = Operator(circ)
# ```
#
# **c.**
# ```
# Both of them will correctly initialize an Operator class object
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: a**
# </details>

# %% [markdown]
# #### 3. Given two operators A and B with the same dimensions, how can you perform the operation B $\otimes$ A ?

# %% [markdown]
# **a.**
# ```
# tens_prod = A.tensor(B)
# ```
#
# **b.**
# ```
# tens_prod = A.expand(B)
# ```
#
# **c.**
# ```
# tens_prod = A.compose(B)
# ```
# <details>
# <summary>Answer</summary>
#
# **Answer: b**
#
# Qiskit uses little-endian ordering.
#
#
# </details>

# %% [markdown]
# ## Section 2. Visualize Quantum Circuits, Measurements and States

# %% [markdown]
# #### 4. Which of the following will draw the circuit with a maximum of 5 layers per line?

# %% [markdown]
# **a.**
# ```
# circ.draw(fold = 5)
# ```
#
# **b.**
# ```
# circ.draw(layers = 5)
# ```
#
# **c.**
# ```
# circ.draw(output = 'mpl', fold = 5)
# ```
# **d.**
# ```
# a and c
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: c**
#
# Qiskit uses little-endian ordering.
#
#
# </details>

# %% [markdown]
# #### 5. Which of the followings will plot the histogram correctly

# %% [markdown]
# ```
# sampler = Sampler()
# job = sampler.run([isa_circuit])
# result = job.result()
# ```
#
# **a.**
# ```
# plot_histogram(result[0].data.meas.get_counts())
# ```
# **b.**
# ```
# plot_histogram(result.data.meas.get_counts())
# ```
# **c.**
# ```
# plot_histogram(result.data.get_counts())
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: a**
#
# </details>

# %% [markdown]
# ## Section 3. Create Quantum Circuits

# %% [markdown]
# #### 6. What does qc.data show?

# %% [markdown]
# **a.**
# ```
# List of operations performed in the circuit.
# ```
# **b.**
# ```
# CircuitInstruction object
# ```
# **c.**
# ```
# QuantumCircuitData object
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: c**
#
# </details>

# %% [markdown]
# #### 7. Which of them construct the following circuit?

# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit(4)
qc.x(0)
qc.y(1)
qc.z(3)
qc.draw(output='mpl')

# %% [markdown]
# **a.**
# ```
# qc_1 = QuantumCircuit(4)
# qc_1.x(0)
#
# qc_2 = QuantumCircuit(2)
# qc_2.y(0)
# qc_2.z(1)
#
# qc = qc_1.append(qc_2)
# ```
# **b.**
# ```
# qc_1 = QuantumCircuit(4)
# qc_1.x(0)
#
# qc_2 = QuantumCircuit(4)
# qc_2.y(0)
# qc_2.z(1)
#
# qc = qc_1.append(qc_2)
# ```
# **c.**
# ```
# qc_1 = QuantumCircuit(4)
# qc_1.x(0)
#
# qc_2 = QuantumCircuit(2)
# qc_2.y(0)
# qc_2.z(1)
#
# qc = qc_1.compose(qc_2, qubits=[1,3])
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: c**
#
# </details>

# %% [markdown]
# #### 8. Knowing that qc.data[0] shows a CircuitInstruction object, which one is the correct way of combining the two following circuits?

# %%
from qiskit import QuantumCircuit
qc_1 = QuantumCircuit(4)
qc_1.x(0)
qc_1.y(3)

qc_2 = QuantumCircuit(2)
qc_2.z(0)

# %% [markdown]
# **a.**
# ```
# inst = qc_2.to_instruction()
# qc_1.append(inst, [1,2])
# ```
# **b.**
# ```
# circinst = qc_2.data[0]
# qc_1.append(circinst, [1,2])
# ```
# **c.**
# ```
# inst = qc_1.to_instruction()
# qc_2.append(inst, [1,2])
# ```
# <details>
# <summary>Answer</summary>
#
# **Answer: a**
#
# </details>

# %% [markdown]
# #### 9. Which of the following measure methods needs predefined classical bits?

# %% [markdown]
# **a.**
# ```
# measure_all()
# ```
# **b.**
# ```
# measure_active()
# ```
# **c.**
# ```
# measure()
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: c**
#
# </details>

# %% [markdown]
# #### 10. Which of the following is not going to raise an error when initializing a parametrized circuit?

# %% [markdown]
# **a.**
# ```
# angle = ParameterVector('angle1', 'angle2')
# qc = QuantumCircuit(1)
# qc.rx(angle[0], 0)
# qc.rx(angle[1], 0)
# ```
# **b.**
# ```
# angle = ParameterVector('angle', 2)
# qc = QuantumCircuit(1)
# qc.rx(angle[0], 0)
# qc.rx(angle[1], 0)
# ```
# **c.**
# ```
# angle = Parameter("angle", 2)
# qc = QuantumCircuit(1)
# qc.rx(angle[0], 0)
# qc.rx(angle[1], 0)
# ```
# <details>
# <summary>Answer</summary>
#
# **Answer: b**
#
# </details>

# %% [markdown]
# #### 11. Which of the following will intialize the parameters correctly?

# %% [markdown]
# **a.**
# ```
# qc.assign_parameters({angle[0]:2, angle[1]:3})
# ```
# **b.**
# ```
# qc = qc.assign_parameters({angle[0]:2, angle[1]:3})
# ```
# **c.**
# ```
# qc = qc.assign_parameters([2,3])
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: b**
#
# </details>

# %% [markdown]
# #### 12. What type of object does qc.parameter show?

# %% [markdown]
# **a.**
# ```
# ParameterVector
# ```
# **b.**
# ```
# ParameterView
# ```
# **c.**
# ```
# A list of Parameter objects
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: b**
#
# </details>

# %% [markdown]
# #### 13. Which of the following is the correct way of preparing a switch statement?

# %% [markdown]
# **a.**
# ```
# with circuit.switch(c0):
#     if c0 == 0:
#         circuit.h(0)
#     if c0 == 1:
#         circuit.x(0)
# ```
# **b.**
# ```
# with circuit.switch(c0):
#     with case(0):
#             circuit.h(0)
#         with case(1):
#             circuit.x(0)
# ```
# **c.**
# ```
# with circuit.switch(c0) as case:
#     with case(0):
#         circuit.h(0)
#     with case(1):
#         circuit.x(0)
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: c**
#
# </details>

# %% [markdown]
# #### 14. Which of the following Passes does not belong to Init stage PassManager?

# %% [markdown]
# **a.**
# ```
# RemoveIdentityEquivalent
# ```
# **b.**
# ```
# InverseCancellation
# ```
# **c.**
# ```
# VF2Layout
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: c**
#
# </details>

# %% [markdown]
# ## 4. Run Quantum Circuits

# %% [markdown]
# #### 15. Which of the following is the correct way of initializing a Session?

# %% [markdown]
# **a.**
# ```
# service = RuntimeService()
# backend = service.backend('ibm_foo')
# session = Session(backend=backend)
# sampler = Sampler(mode=session)
# job = sampler.run([isa_circ])
# session.close()
# ```
# **b.**
# ```
# service = RuntimeService()
# backend = service.backend('ibm_foo')
# with Session(backend=backend):
#     sampler = Sampler()
#     job = sampler.run([isa_circ])
# ```
# **c.**
# ```
# Both of them.
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: c**
#
# </details>

# %% [markdown]
# ## 5. Sampler Primitive

# %% [markdown]
# #### 16. Which of the following is not an allowed PUB for sampler primitive?

# %% [markdown]
# **a.**
# ```
# (non-parametric-isa-circ, None, shots)
# ```
# **b.**
# ```
# (parametric-isa-circ, parameter-values)
# ```
# **c.**
# ```
# (non-parametric-isa-circ,)
# ```
# **d.**
# ```
# (parametric-isa-circ,)
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: d**
#
# </details>

# %% [markdown]
# #### 17. Select the output from the following code

# %% [markdown]
# ```
# pub = (isa_circ, None, 2000)
# job = sampler.run([pub])
# result = job.result()
# print(type(result[0].data.meas))
# ```

# %% [markdown]
# **a.**
# ```
# <class 'qiskit.primitives.containers.bit_array.BitArray'>
# ```
# **b.**
# ```
# <class 'qiskit.primitives.containers.data_bin.DataBin'>
# ```
# **c.**
# ```
# <class 'qiskit.primitives.containers.sampler_pub_result.SamplerPubResult'>
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: a**
#
# </details>

# %% [markdown]
# #### 18. How many times will the following circuit be measured?

# %% [markdown]
# ```
# from qiskit_ibm_runtime import SamplerV2 as Sampler
# sampler = Sampler(mode = backend)
# isa_circ = pm.run(qc)
# pub = (isa_circ, None, 2000)
# job = sampler.run([pub], shots=1000)
# ```

# %% [markdown]
# **a.**
# ```
# The default number of times that is set in the SamplerV2 code
# ```
# **b.**
# ```
# 1000 times
# ```
# **c.**
# ```
# 2000 times
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: c**
#
# </details>

# %% [markdown]
# ## Estimator Primitive

# %% [markdown]
# #### 19. Which of the following is the correct way of running estimator?

# %% [markdown]
# **a.**
# ```
# pm = generate_preset_pass_manager(optimization_level=1, backend=backend)
# isa_circ = pm.run(qc)
# isa_obs = obs.apply_layout(isa_circ.layout)
# pub = (isa_circ, isa_obs)
# job = estimator.run(pub)
# ```
# **b.**
# ```
# pm = generate_preset_pass_manager(optimization_level=1, backend=backend)
# isa_circ = pm.run(qc)
# isa_obs = obs.apply_layout(isa_circ.layout)
# pub = (isa_circ, isa_obs)
# job = estimator.run([pub])
# ```
# **c.**
# ```
# pm = generate_preset_pass_manager(optimization_level=1, backend=backend)
# isa_circ = pm.run(qc)
# isa_obs = pm.run(obs)
# pub = (isa_circ, isa_obs)
# job = estimator.run([pub])
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: b**
#
# </details>

# %% [markdown]
# #### 20. Which is the correct way of extracting the expected value of isa_obs2 given the following code?

# %% [markdown]
# ```
# pub1 = (isa_circ, isa_obs1)
# pub2 = (isa_circ, isa_obs2)
# job = estimator.run([pub1, pub2])
# result = job.result()
# ```

# %% [markdown]
# **a.**
# ```
# result[1].data.evs
# ```
# **b.**
# ```
# result.isa_obs2.data.evs
# ```
# **c.**
# ```
# result.data.evs[1]
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: a**
#
# </details>

# %% [markdown]
# #### 21. How can you add dynamical_decoupling to the estimator?

# %% [markdown]
# **a.**
# ```
# By setting the resilience level to the highest number possible (2)
# ```
# **b.**
# ```
# It is not needed to set the resilience to level 2, it is already included in resilience level 1.
# ```
# **c.**
# ```
# It is not possible to add dynamical_decoupling through the resilience level, it must be done through estimator.options
# ```
#
# <details>
# <summary>Answer</summary>
#
# **Answer: c**
#
# </details>
